# %% [markdown]
# # DOG?????????? TO PARK RATIO?
# ## By team Buckingham Badger Szesterniak. (Joey + Bianca)

# %% [markdown]
# #### We just wanted to find the city with the most amount of good boys and dogs that had a place to run around in near by!!

# %%
cd Untitled\ Folder
# Out:
# /ihome/cmpinf0999_2018f/biv5/Untitled Folder

# %% [markdown]
# # INTRO
#
# The best neighborhood in Pittsburgh need two crucial things that qualify it as the best: dogs and parks. We wanted to take in data from all of the dogs in Allegheny County that correspond to zip codes that have parks. From there, we found the most number of dogs in the zip code with a park, and broke down data containing the names of the dogs, finding the most common names. We decided that the best dog name in the best neighborhood in Pittsburgh had to be the longest name in said neighborhood, making our team name the best dog name in all of Allegheny County.

# %%
import pandas as pd

# %% [markdown]
# pandas

# %%
dog_data = pd.read_csv("2018-08.csv") 
park_data = pd.read_csv("Allegheny_County_Parks_Outlines.csv")

# %% [markdown]
# setting up the data in general

# %%
dog_data.head(10)
# Out:
#                                       LicenseType               Breed  \
# 0                      Dog Lifetime Spayed Female           BOXER MIX
# 1               Dog Senior Lifetime Neutered Male        AUS SHEPHERD
# 2                      Dog Lifetime Neutered Male           HOUND MIX
# 3                               Dog Lifetime Male             SAMOYED
# 4                           Dog Individual Female  LABRADOR RETRIEVER
# 5               Dog Senior Lifetime Spayed Female           CHIHUAHUA
# 6                    Dog Individual Neutered Male            COCKAPOO
# 7  Dog Senior Citizen or Disability Neutered Male        GER SHEPHERD
# 8           Dog Senior Citizen or Disability Male       BELG MALINOIS
# 9                    Dog Individual Neutered Male               MIXED
#
#          Color                DogName  OwnerZip  ExpYear         ValidDate
# 0      BRINDLE              STARLETTE     15131     2018   9/22/2008 13:23
# ...

# %% [markdown]
# setting up the dogs

# %%
park_data.head(10)
# Out:
#    FID                 NAME     Shape_Leng Name_Short                Address  \
# 0    2  Harrison Hills Park   41175.209855         HH       5200 Freeport Rd
# 1    3  Hartwood Acres Park   30555.377129         HA     200 Hartwood Acres
# 2    4           North Park  101552.165124         NP         Pearce Mill Rd
# 3    6           South Park   68738.717451         SP             Buffalo Dr
# 4    7       White Oak Park   39002.872657         WO              3 Muse Ln
# 5    8           Boyce Park   39703.116418         BP  675 Old Frankstown Rd
# 6    9  Settlers Cabin Park   38072.218703         SC           608 Ridge Rd
# 7   11      Deer Lakes Park            NaN         DL    1090 Baileys Run Rd
# 8   13      Round Hill Park            NaN         RH      651 Round Hill Rd
#
#                                             ImageURL  \
# 0  http://www.alleghenycounty.us/uploadedImages/A...
# 1  http://www.alleghenycounty.us/uploadedImages/A...
# ...

# %% [markdown]
# setting up the parks

# %%
dog_data['OwnerZip'].value_counts().plot(kind="barh",figsize = (10,22))

# %% [markdown]
# this is for finding out where /all/ the dogs live

# %%
query_mask = dog_data['OwnerZip'] == 15129
I5129dogs = dog_data[query_mask]
I5129dogs.head()
# Out:
#                       LicenseType              Breed    Color  DogName  \
# 11   Dog Individual Neutered Male   SCOTTISH TERRIER    BLACK   BAILEY
# 265  Dog Individual Spayed Female         CANE CORSO  BRINDLE      NYX
# 346  Dog Individual Spayed Female       SHIH TZU MIX    WHITE    CHLOE
# 347  Dog Individual Neutered Male       SHIH TZU MIX    BLACK  CHARLIE
# 348  Dog Individual Spayed Female  SHETLAND SHEEPDOG    BLACK     ZOEY
#
#      OwnerZip  ExpYear         ValidDate
# 11      15129     2018  11/27/2017 10:09
# 265     15129     2018  11/28/2017 10:47
# 346     15129     2018  11/28/2017 15:27
# 347     15129     2018  11/28/2017 15:27
# 348     15129     2018  11/28/2017 15:27

# %%
park_data['Zip'].value_counts().plot(kind="barh",figsize = (10,22))

# %% [markdown]
# this is for finding all the relevant zip codess

# %%
query_mask = dog_data['OwnerZip'] == 15205
I5205dogs = dog_data[query_mask]
I5205dogs.head()
# Out:
#                                         LicenseType              Breed  \
# 45                     Dog Individual Spayed Female  DOBERMAN PINSCHER
# 63                              Dog Individual Male       AUS SHEPHERD
# 64                     Dog Individual Spayed Female            LAB MIX
# 103  Dog Senior Citizen or Disability Spayed Female        RAT TERRIER
# 234                    Dog Individual Spayed Female            LAB MIX
#
#                  Color   DogName  OwnerZip  ExpYear         ValidDate
# 45         BLACK/BROWN  VALKYRIE     15205     2018  11/27/2017 11:46
# 63   WHITE/BLACK/BROWN    BANDIT     15205     2018  11/27/2017 11:36
# 64               MULTI     KARMA     15205     2018  11/27/2017 11:36
# 103  WHITE/BLACK/BROWN      IZZY     15205     2018  11/27/2017 13:33
# 234              WHITE    SERRIA     15205     2018  11/28/2017 11:41

# %%
query_mask = dog_data['OwnerZip'] == 15238
I5238dogs = dog_data[query_mask]
I5238dogs.head()
# Out:
#                                        LicenseType              Breed  \
# 7   Dog Senior Citizen or Disability Neutered Male       GER SHEPHERD
# 8            Dog Senior Citizen or Disability Male      BELG MALINOIS
# 13                    Dog Individual Neutered Male      DACHSHUND MIX
# 14                    Dog Individual Spayed Female  SHETLAND SHEEPDOG
# 17                    Dog Individual Neutered Male       BICHON FRISE
#
#           Color     DogName  OwnerZip  ExpYear         ValidDate
# 7   BLACK/BROWN      TACODA     15238     2018  11/27/2017 10:03
# 8       BRINDLE        EICH     15238     2018  11/27/2017 10:03
# 13  WHITE/BROWN       LEROI     15238     2018  11/27/2017 10:16
# 14  WHITE/BROWN  ZOE VITSAS     15238     2018  11/27/2017 10:17
# 17        WHITE        DUDE     15238     2018  11/27/2017 10:29

# %%
query_mask = dog_data['OwnerZip'] == 15239
I5239dogs = dog_data[query_mask]
I5239dogs.head()
# Out:
#                       LicenseType         Breed              Color  \
# 25   Dog Individual Spayed Female   TERRIER MIX            SPOTTED
# 37   Dog Individual Neutered Male  DOBERMAN MIX              BLACK
# 76   Dog Individual Spayed Female     BOXER MIX              BROWN
# 104  Dog Individual Spayed Female      KEESHOND  WHITE/BLACK/BROWN
# 110         Dog Individual Female  MIN PINSCHER        BLACK/BROWN
#
#          DogName  OwnerZip  ExpYear         ValidDate
# 25         ANNIE     15239     2018  11/27/2017 15:37
# 37         HOWIE     15239     2018  11/27/2017 16:09
# 76         BALEY     15239     2018  11/27/2017 15:37
# 104  CISSIE BEAR     15239     2018  11/27/2017 15:27
# 110        TONKS     15239     2018   11/29/2017 9:47

# %%
query_mask = dog_data['OwnerZip'] == 15065
I5065dogs = dog_data[query_mask]
I5065dogs.head()
# Out:
#                                         LicenseType               Breed  \
# 157  Dog Senior Citizen or Disability Spayed Female        SHIH TZU MIX
# 189                    Dog Individual Spayed Female  GOLDEN RETRIEV MIX
# 250                           Dog Individual Female               BOXER
# 298                    Dog Individual Neutered Male        BICHON FRISE
# 336  Dog Senior Citizen or Disability Neutered Male                 PUG
#
#            Color DogName  OwnerZip  ExpYear         ValidDate
# 157        BROWN    PEPA     15065     2018  11/27/2017 15:37
# 189         GOLD     ZOE     15065     2018  11/27/2017 15:27
# 250        BROWN   PENNY     15065     2018  11/28/2017 10:27
# 298        WHITE   RANGO     15065     2018  11/28/2017 10:27
# 336  WHITE/BLACK   MUGSY     15065     2018  11/28/2017 11:47

# %%
query_mask = dog_data['OwnerZip'] == 15037
I5037dogs = dog_data[query_mask]
I5037dogs.head()
# Out:
#                                  LicenseType             Breed        Color  \
# 246  Dog Senior Citizen or Disability Female         SIB HUSKY  WHITE/BLACK
# 380             Dog Individual Spayed Female        ENG SETTER      SPOTTED
# 523             Dog Individual Spayed Female  AM WATER SPANIEL        BROWN
# 524             Dog Individual Spayed Female  AM WATER SPANIEL        BROWN
# 530                      Dog Individual Male             BOXER         FAWN
#
#     DogName  OwnerZip  ExpYear         ValidDate
# 246   PANDA     15037     2018  11/28/2017 11:41
# 380   BELLA     15037     2018  11/28/2017 11:54
# 523  HANNAH     15037     2018  11/28/2017 15:55
# 524   HOLLY     15037     2018  11/28/2017 15:55
# 530  GUNNER     15037     2018  11/28/2017 15:55

# %%
query_mask = dog_data['OwnerZip'] == 15131
I5131dogs = dog_data[query_mask]
I5131dogs.head()
# Out:
#                       LicenseType             Breed        Color    DogName  \
# 0      Dog Lifetime Spayed Female         BOXER MIX      BRINDLE  STARLETTE
# 36   Dog Individual Spayed Female  GER SHEPHERD MIX  BLACK/BROWN      SABLE
# 43   Dog Individual Spayed Female  GER SHEPHERD MIX  BLACK/BROWN      SABLE
# 102  Dog Individual Spayed Female           LAB MIX        BLACK   PENELOPE
# 124  Dog Individual Neutered Male         CHIHUAHUA        BROWN     RUBBLE
#
#      OwnerZip  ExpYear         ValidDate
# 0       15131     2018   9/22/2008 13:23
# 36      15131     2018               NaN
# 43      15131     2018  11/27/2017 16:03
# 102     15131     2018               NaN
# 124     15131     2018  11/27/2017 15:27

# %%
query_mask = dog_data['OwnerZip'] == 15084
I5084dogs = dog_data[query_mask]
I5084dogs.head()
# Out:
#                       LicenseType                Breed      Color  DogName  \
# 275  Dog Individual Spayed Female              LAB MIX      BLACK    MOLLY
# 321  Dog Individual Neutered Male     GOLDEN RETRIEVER       GOLD    CRUSH
# 384  Dog Individual Neutered Male         AUS SHEPHERD      MULTI    COLBY
# 385  Dog Individual Neutered Male       GREAT PYRENEES      WHITE     THOR
# 432  Dog Individual Neutered Male  WELSH CORGI PEMBROK  WHITE/RED  BUTTERS
#
#      OwnerZip  ExpYear         ValidDate
# 275     15084     2018  11/28/2017 10:47
# 321     15084     2018  11/28/2017 13:53
# 384     15084     2018  11/28/2017 12:13
# 385     15084     2018  11/28/2017 12:13
# 432     15084     2018  11/28/2017 15:06

# %%
query_mask = dog_data['OwnerZip'] == 15101
I5101dogs = dog_data[query_mask]
I5101dogs.head()
# Out:
#                       LicenseType       Breed      Color          DogName  \
# 58   Dog Individual Neutered Male      MORKIE    SPOTTED  NORMAN MITCHELL
# 210  Dog Individual Neutered Male    PEEKAPOO      WHITE             DUDE
# 230  Dog Individual Neutered Male     LAB MIX        TAN           BOSTON
# 236  Dog Individual Neutered Male  BEAGLE MIX  TRI-COLOR          LINCOLN
# 423  Dog Individual Neutered Male   BOXER MIX        TAN           BANDIT
#
#      OwnerZip  ExpYear         ValidDate
# 58      15101     2018   11/29/2017 9:47
# 210     15101     2018  11/27/2017 15:38
# 230     15101     2018  11/28/2017 10:26
# 236     15101     2018  11/28/2017 10:26
# 423     15101     2018   11/29/2017 8:46

# %% [markdown]
# this whole part is to set up the data filtered by postal code

# %%
print(I5129dogs.count())
print(I5205dogs.count())
print(I5238dogs.count())
print(I5239dogs.count())
print(I5065dogs.count())
print(I5037dogs.count())
print(I5131dogs.count())
print(I5084dogs.count())
print(I5101dogs.count())
# Out:
# LicenseType    362
# Breed          362
# Color          362
# DogName        362
# OwnerZip       362
# ExpYear        362
# ValidDate      362
# dtype: int64
# LicenseType    571
# Breed          571
# Color          571
# DogName        571
# OwnerZip       571
# ExpYear        571
# ValidDate      562
# dtype: int64
# LicenseType    537
# Breed          537
# Color          537
# DogName        537
# OwnerZip       537
# ExpYear        537
# ValidDate      532
# dtype: int64
# LicenseType    996
# Breed          996
# Color          996
# DogName        996
# OwnerZip       996
# ExpYear        996
# ValidDate      992
# dtype: int64
# LicenseType    633
# Breed          633
# Color          633
# DogName        633
# OwnerZip       633
# ExpYear        633
# ValidDate      626
# dtype: int64
# LicenseType    492
# Breed          492
# Color          492
# DogName        492
# OwnerZip       492
# ExpYear        492
# ValidDate      486
# dtype: int64
# LicenseType    289
# ...

# %% [markdown]
# this parts for finding the most amount of good boys

# %%
I5239dogs['DogName'].value_counts().plot(kind="barh",figsize = (10,88))

# %% [markdown]
# this is where u find all the dogs from plum

# %% [markdown]
# ## Conclusions
#
# ### Joey
#
# I am not familiar with many neighborhoods in Pittsburgh, but for some reason I thought that Mount Washington was probably the best neighborhood. The view of the city is just sOoOoOo cool, but as it turns out, I was mistaken! Clearly, the best neighborhood in all of Allegheny County is Plum, Pennsylvania because the dog:park ratio is unbeatable! Although I have never been there, the data proves that I am definitely missing out.
#
# ### Bianca
#
# Having only gone to Pitt's campus (pretty much) every time I've been in Pittsburgh, I didn't necessarily have a favorite neighborhood. I hadn't seen enough of it to make a judgement like that, but now it is clear that there is one supreme neighborhood, and that is Plum where all the best puppers are. Chi Chi Bean, one of my favorite dogs (based on the data) will forever be in my heart and if I ever go to plum, I will find that doggo.
#
# ### SO!
#
# Dogs are the best and the best dog of all the best dogs is Buckingham Badger Szesterniak.
